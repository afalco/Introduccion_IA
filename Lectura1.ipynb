# %% [markdown]
# <a href="https://colab.research.google.com/github/afalco/Introduccion_IA/blob/main/Lectura1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import rcParams
import matplotlib.image as mpimg
rcParams ['figure.dpi'] = 120
import matplotlib.pyplot as plt
from scipy import fftpack
img_color = plt.imread ('imagen.jpg')

# %% [markdown]
# Vamos a seguir adelante con la práctica
#
# **Esto es en negrita**
#
# Podemos escribir funciones como en las transparencias
#
# $$
# \mathrm{Im}: \{0,1,\ldots,H-1\} \times \{0,1,\ldots,W-1\} \times \{0,1,2\} \longrightarrow \mathbb{R}
# $$

# %%
print ("Tamano : %s"%(repr (img_color.shape )),"\n")
print ("Tipo : %s " %(img_color.dtype) ,"\n" )
print ( "Intensidad del pixel en la posicion 0 , 0: %s "%( repr (
img_color [0 , 0 , :]) ) ,"\n")
# Out:
# Tamano : (835, 1300, 3)
#
# Tipo : uint8
#
# Intensidad del pixel en la posicion 0 , 0: array([ 88,  43, 232], dtype=uint8)

# %% [markdown]
# **Vamos a ver la figura**

# %%
plt.figure (figsize =(6,4),tight_layout = True)
plt.imshow (img_color)
plt.show ()

# %%
plt.figure (figsize =(6,3),tight_layout = True)
plt.imshow (img_color [500:800 , 1000:1200]);
plt.show()
